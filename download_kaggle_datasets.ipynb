# %% [markdown]
# <a href="https://colab.research.google.com/github/ajenningsfrankston/download_kaggle_datasets/blob/main/download_kaggle_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/kaggle_datasets"

# %%
# !pip install kaggle

# %%
# %cd /content/gdrive/My Drive/kaggle_datasets
# Out:
# /content/gdrive/My Drive/kaggle_datasets

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              234KB  2021-07-20 07:51:04           9598
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           5839
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           2158
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-07-03 18:37:20           2465
# ...

# %%
# !kaggle datasets download -d jonathanbesomi/rsna-miccai-png
# Out:
# ...
# 100% 5.08G/5.08G [01:51<00:00, 70.7MB/s]
# 100% 5.08G/5.08G [01:51<00:00, 48.8MB/s]

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/00834/FLAIR/Image-114.png
#   inflating: train/00834/FLAIR/Image-115.png
#   inflating: train/00834/FLAIR/Image-116.png
#   inflating: train/00834/FLAIR/Image-117.png
#   inflating: train/00834/FLAIR/Image-118.png
#   inflating: train/00834/FLAIR/Image-119.png
#   inflating: train/00834/FLAIR/Image-120.png
#   inflating: train/00834/FLAIR/Image-121.png
#   inflating: train/00834/FLAIR/Image-122.png
#   inflating: train/00834/FLAIR/Image-123.png
#   inflating: train/00834/FLAIR/Image-124.png
#   inflating: train/00834/FLAIR/Image-125.png
#   inflating: train/00834/FLAIR/Image-126.png
#   inflating: train/00834/FLAIR/Image-127.png
#   inflating: train/00834/FLAIR/Image-128.png
#   inflating: train/00834/FLAIR/Image-129.png
#   inflating: train/00834/FLAIR/Image-130.png
#   inflating: train/00834/FLAIR/Image-131.png
#   inflating: train/00834/FLAIR/Image-132.png
#   inflating: train/00834/FLAIR/Image-133.png
# ...

# %%
os.listdir('/content/gdrive/MyDrive/kaggle_datasets/train')
# Out:
# ['00000',
#  '00002',
#  '00003',
#  '00005',
#  '00006',
#  '00008',
#  '00009',
#  '00011',
#  '00012',
#  '00014',
#  '00017',
#  '00018',
#  '00019',
#  '00020',
#  '00021',
#  '00022',
#  '00024',
#  '00025',
#  '00026',
#  '00028',
#  '00030',
#  '00031',
#  '00032',
#  '00033',
#  '00035',
#  '00036',
#  '00043',
#  '00044',
#  '00045',
#  '00046',
#  '00048',
#  '00049',
#  '00052',
#  '00053',
#  '00054',
#  '00056',
#  '00058',
#  '00059',
#  '00060',
#  '00061',
#  '00062',
#  '00063',
#  '00064',
#  '00066',
#  '00068',
#  '00070',
#  '00071',
#  '00072',
#  '00074',
#  '00077',
#  '00078',
#  '00081',
#  '00084',
#  '00085',
#  '00087',
#  '00088',
#  '00089',
#  '00090',
#  '00094',
#  '00095',
#  '00096',
#  '00097',
#  '00098',
#  '00099',
#  '00100',
#  '00102',
#  '00104',
#  '00105',
#  '00106',
#  '00107',
#  '00108',
#  '00109',
#  '00110',
#  '00111',
#  '00112',
#  '00113',
#  '00116',
#  '00117',
#  '00120',
#  '00121',
#  '00122',
#  '00123',
#  '00124',
# ...
